# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("data/hotel_bookings.csv")

# %%
data
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
data.head()
#indexy první sloupec
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
data.tail()
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 119385  City Hotel            0         23               2017
# 119386  City Hotel            0        102               2017
# 119387  City Hotel            0         34               2017
# 119388  City Hotel            0        109               2017
# 119389  City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 119385             August                        35
# 119386             August                        35
# 119387             August                        35
# 119388             August                        35
# 119389             August                        35
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 119385                         30                        2
# 119386                         31                        2
# 119387                         31                        2
# ...

# %%
data.columns # vrací seznam názvů všech sloupečků
a = data["hotel"] #dataframe["hotel"] - dostanu hodnoty 
a
#type(a)  dostanu jen series
# Out:
# 0         Resort Hotel
# 1         Resort Hotel
# 2         Resort Hotel
# 3         Resort Hotel
# 4         Resort Hotel
#               ...
# 119385      City Hotel
# 119386      City Hotel
# 119387      City Hotel
# 119388      City Hotel
# 119389      City Hotel
# Name: hotel, Length: 119390, dtype: object

# %%
data.iloc[:,0]  # způsob jak můžeme dostat hodnoty pomocí indexu
# nejprve vybírám řádky a pak teprve sloupce 
# řádky
data.iloc[0:2] # první dva řádky, dvojka značí, že to chci po řádek 2, dvojka už tam nebude 
# sloupce
data.iloc[0:2, 1:5] # jen prvních 5 sloupců
# Out:
#    is_canceled  lead_time  arrival_date_year arrival_date_month
# 0            0        342               2015               July
# 1            0        737               2015               July

# %%
data[["hotel","is_canceled","meal"]] # už je to seznam, musím dát dvoje hranaté závorky
# Out:
#                hotel  is_canceled meal
# 0       Resort Hotel            0   BB
# 1       Resort Hotel            0   BB
# 2       Resort Hotel            0   BB
# 3       Resort Hotel            0   BB
# 4       Resort Hotel            0   BB
# ...              ...          ...  ...
# 119385    City Hotel            0   BB
# 119386    City Hotel            0   BB
# 119387    City Hotel            0   BB
# 119388    City Hotel            0   BB
# 119389    City Hotel            0   HB
#
# [119390 rows x 3 columns]

# %%
data[["hotel"]]
# Out:
#                hotel
# 0       Resort Hotel
# 1       Resort Hotel
# 2       Resort Hotel
# 3       Resort Hotel
# 4       Resort Hotel
# ...              ...
# 119385    City Hotel
# 119386    City Hotel
# 119387    City Hotel
# 119388    City Hotel
# 119389    City Hotel
#
# [119390 rows x 1 columns]

# %% [markdown]
# ## Unique

# %%
data["deposit_type"].unique() #dostanu seznam, a v něm všechny hodnoty, které se tam vyskytují kdekoliv
# Out:
# array(['No Deposit', 'Refundable', 'Non Refund'], dtype=object)

# %%
data["hotel"].unique()
# Out:
# array(['Resort Hotel', 'City Hotel'], dtype=object)

# %%
data["arrival_date_month"].unique()
# Out:
# array(['July', 'August', 'September', 'October', 'November', 'December',
#        'January', 'February', 'March', 'April', 'May', 'June'],
#       dtype=object)

# %%
##Dotazy

# %%
# napíšu si podmínku data["hotel"] == "City Hotel" a pak to vložím do hranatých závorek
#data["hotel"] == "City Hotel"  # takhle to vrací jen True a False
data[data["hotel"] == "City Hotel"] # ale když chci k tomu všechny sloupečky, 
# musím před to dát název dataframu a celé do hranatých
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 40060   City Hotel            0          6               2015
# 40061   City Hotel            1         88               2015
# 40062   City Hotel            1         65               2015
# 40063   City Hotel            1         92               2015
# 40064   City Hotel            1        100               2015
# ...            ...          ...        ...                ...
# 119385  City Hotel            0         23               2017
# 119386  City Hotel            0        102               2017
# 119387  City Hotel            0         34               2017
# 119388  City Hotel            0        109               2017
# 119389  City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 40060                July                        27
# 40061                July                        27
# 40062                July                        27
# ...

# %%
#podminka1 = data["hotel"] == "City Hotel" 
#podminka2 = data["deposit_type"] == "No Deposit"

#data[(podminka1)&(podminka2)]

data[(data["hotel"] == "City Hotel") & (data["deposit_type"] == "No Deposit")] #chci jen cityhotel se bez zálohy
data[(data["hotel"] == "City Hotel") | (data["deposit_type"] == "No Deposit")] #chci jen cityhotel nebo nez zálohy
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
data_mestske_bez_zalohy = data[(data["hotel"] == "City Hotel") |
     (data["deposit_type"] == "No Deposit")
    ]

# %%
data_mestske_bez_zalohy.shape  # počet řádků, počet sloupečků
# Out:
# (117529, 32)

# %%
data_mestske_bez_zalohy.info() # řádky, sloupce, index, jméno, počet nenulových hodnot
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 117529 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           117529 non-null  object
#  1   is_canceled                     117529 non-null  int64
#  2   lead_time                       117529 non-null  int64
#  3   arrival_date_year               117529 non-null  int64
#  4   arrival_date_month              117529 non-null  object
#  5   arrival_date_week_number        117529 non-null  int64
#  6   arrival_date_day_of_month       117529 non-null  int64
#  7   stays_in_weekend_nights         117529 non-null  int64
#  8   stays_in_week_nights            117529 non-null  int64
#  9   adults                          117529 non-null  int64
#  10  children                        117525 non-null  float64
#  11  babies                          117529 non-null  int64
# ...

# %%
data_mestske_bez_zalohy.describe() # základní statistika
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  117529.000000  117529.000000      117529.000000
# mean        0.362055     102.780216        2016.160692
# std         0.480597     106.523307           0.707318
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      68.000000        2016.000000
# 75%         1.000000     158.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             117529.000000              117529.000000
# mean                  27.183631                  15.794902
# std                   13.597330                   8.769206
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 help(describe)
#
# NameError: name 'describe' is not defined

# %% [markdown]
# ## Vizualizace

# %%
#countplot je sloupcový graf 
sns.countplot(data = data, x = "hotel", hue = "is_canceled") # chci to podle toho, jestli chci canceled
# Out:
# <AxesSubplot: xlabel='hotel', ylabel='count'>

# %%
data["hotel"].value_counts(ascending=True)  # když chci vidět čísla, kolik ji tam je
# parametr ascending je defaultně False (od nejvetšího po nejmenší, ale mohu dát i naopak)
# Out:
# Resort Hotel    40060
# City Hotel      79330
# Name: hotel, dtype: int64

# %%
month_sorted = ['January', 'February', 'March', 'April', 'May', 'June',
                'July', 'August', 'September', 'October', 'November', 'December']
ax = sns.countplot(x=data["arrival_date_month"], order = month_sorted)

ax.set(xlabel = "Month",
      ylabel = "Count",
      title = "Muj graf")
ax.tick_params(axis = 'x', rotation = 45) # tick = ticky na osách

# %%
sns.histplot(data=data, x="lead_time")
# Out:
# <AxesSubplot: xlabel='lead_time', ylabel='Count'>

# %%
data_lead_year = data[data["lead_time"] <= 365]

ax = sns.histplot(data=data_lead_year, x="lead_time", hue = "is_canceled", multiple = "stack") #multiple = "stack"
# objekt ax, je to takový úzus, že se jmenuje ax
ax.set(title = "Histogram")
ax.legend(labels=["no","yes"])

# %%
#cvičení
"stays_in_week_nights"
# Out:
# 'stays_in_week_nights'

# %% [markdown]
# Cvičení
# Rozhodnutí o zrušení rezervace může záviset na tom, jak dlouho uživatelé plánují v hotelu zůstat.
#
# Začni s počtem ve všední den (stays_in_week_nights). V datech jsou některé pobyty s extrémně dlouhou dobou. Napiš dotaz, který vytvoří tabulku, kde jsou pobyty kratší než 10 všedních dní. Poté vytvoř graf, který zobrazuje počty zrušených a nezrušených rezervací dle počtu všechních dní, na které je rezervace plánována.
# Nyní budeme uvažovat celkovou délku pohybu. Vytvoř sloupec total_length, který bude dán součtem sloupců stays_in_weekend_nights a stays_in_week_nights. Pomocí dotazu dále vytvoř tabulku, která bude obsahovat pouze řádky s hodnotou ve sloupci total_length větší než 0 (rezervace s nulovou délkou jsou totiž podivnosti, které z naší analýzy vyřadíme) a současně menší než 10.
# Do zrušení rezervace může zasahovat i cena. Protože cena služeb obecně silně závisí na zemi, ve které hotel je, vybereme jen jednu zemi. Podívej se na sloupec country a vyber druhou nejčastěji se vyskytující zemi. Cena za pokoj je ve sloupci adr. Opět je potřeba zbavit se extrémních pozorování, uvažuj pouze řádky s hodnotou adr do 300. Poté vytvoř graf, který zobrazuje počty zrušených a nezrušených rezervací v závislosti na její ceně.

# %%
kratsi_nez_deset = data[data["stays_in_week_nights"] <= 10]
ax = sns.countplot(x="stays_in_week_nights",hue = "is_canceled", data = kratsi_nez_deset) 
ax.set(label = "number of week nights ")
ax.legend(labels=["no","yes"], title = "Canceled")

# %%
data["stays_in_week_nights"]
# Out:
# 0         0
# 1         0
# 2         1
# 3         1
# 4         2
#          ..
# 119385    5
# 119386    5
# 119387    5
# 119388    5
# 119389    7
# Name: stays_in_week_nights, Length: 119390, dtype: int64

# %% [markdown]
# Nyní budeme uvažovat celkovou délku pohybu. Vytvoř sloupec total_length, který bude dán součtem sloupců stays_in_weekend_nights a stays_in_week_nights. Pomocí dotazu dále vytvoř tabulku, která bude obsahovat pouze řádky s hodnotou ve sloupci total_length větší než 0 (rezervace s nulovou délkou jsou totiž podivnosti, které z naší analýzy vyřadíme) a současně menší než 10.

# %%
data['total_length'] = data['stays_in_weekend_nights'] + data['stays_in_week_nights']

# %%
data[(data['total_length'] > 0) & (data['total_length'] < 10)]
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# 5       Resort Hotel            0         14               2015
# 6       Resort Hotel            0          0               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 2                    July                        27
# 3                    July                        27
# ...

# %% [markdown]
# Do zrušení rezervace může zasahovat i cena. Protože cena služeb obecně silně závisí na zemi, ve které hotel je, vybereme jen jednu zemi. Podívej se na sloupec country a vyber druhou nejčastěji se vyskytující zemi. Cena za pokoj je ve sloupci adr. Opět je potřeba zbavit se extrémních pozorování, uvažuj pouze řádky s hodnotou adr do 300. Poté vytvoř graf, který zobrazuje počty zrušených a nezrušených rezervací v závislosti na její ceně.

# %%
zeme = data["country"].value_counts(ascending=False)

# %%
zeme[["GBR"]]
# Out:
# GBR    12129
# Name: country, dtype: int64

# %%
data[["country","adr"]]
# Out:
#        country     adr
# 0          PRT    0.00
# 1          PRT    0.00
# 2          GBR   75.00
# 3          GBR   75.00
# 4          GBR   98.00
# ...        ...     ...
# 119385     BEL   96.14
# 119386     FRA  225.43
# 119387     DEU  157.71
# 119388     GBR  104.40
# 119389     DEU  151.20
#
# [119390 rows x 2 columns]

# %%
data_adr = data[(data["country"]== 'GBR') & (data["adr"] < 300)]
sns.histplot(data = data_adr, hue = "is_canceled", x = "adr", multiple = "stack")
# Out:
# <AxesSubplot: xlabel='adr', ylabel='Count'>
